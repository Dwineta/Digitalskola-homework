# %%
import urllib.request, json, timeit, pandas as pd

# %%
shopee_url = "https://shopee.co.id/api/v4/search/search_items?by=relevancy&keyword=salep%2088&limit=60&newest=0&order=desc&page_type=search&scenario=PAGE_GLOBAL_SEARCH&version=2"
print(shopee_url)
# Out:
# https://shopee.co.id/api/v4/search/search_items?by=relevancy&keyword=salep%2088&limit=60&newest=0&order=desc&page_type=search&scenario=PAGE_GLOBAL_SEARCH&version=2

# %%
start=timeit.default_timer()
df_shopee_item_append=pd.DataFrame()

shopee_url = "https://shopee.co.id/api/v4/search/search_items?by=relevancy&keyword=salep%2088&limit=60&newest=0&order=desc&page_type=search&scenario=PAGE_GLOBAL_SEARCH&version=2"
print(shopee_url)
with urllib.request.urlopen(shopee_url) as url:
    data_shopee = json.loads(url.read().decode())
    
    df_shopee=pd.DataFrame.from_dict(data_shopee,orient='index')
    df_shopee=pd.DataFrame(df_shopee.transpose())
    df_shopee_item=pd.DataFrame(df_shopee['items'])
    df_shopee_item=pd.DataFrame(df_shopee_item['items'].values.tolist())
    df_shopee_item=df_shopee_item.transpose()
    df_shopee_item=pd.DataFrame(df_shopee_item[0].values.tolist())
    print(len(df_shopee_item_append))
    df_shopee_item_append=df_shopee_item_append.append(df_shopee_item,ignore_index=True)
    print(len(df_shopee_item_append))
    print('---------------')
    
stop=timeit.default_timer()
print('Time: ',stop - start)
# Out:
# https://shopee.co.id/api/v4/search/search_items?by=relevancy&keyword=salep%2088&limit=60&newest=0&order=desc&page_type=search&scenario=PAGE_GLOBAL_SEARCH&version=2
# 0
# 60
# ---------------
# Time:  0.5080551110004308

# %%
print(data_shopee)
# Out:
# {'bff_meta': None, 'error': None, 'error_msg': None, 'reserved_keyword': None, 'suggestion_algorithm': None, 'algorithm': 'eyJzZWFyY2giOiIwLmEuMzE2NkBFUklQUVBJV0ZNVVVWRlJZMEdWTUUxRVREWUVHRVMyUFExOU9OMzVHTzE0OSJ9', 'total_count': 7789, 'nomore': False, 'items': [{'item_basic': {'itemid': 6815585430, 'shopid': 185943783, 'name': 'Salep Kulit 88, Isi 6 Gram, Atasi Gatal Kulit Akibat Bakteri Dan Jamur', 'label_ids': [1000544, 1000653, 1000559, 1000560, 1000246, 1001345, 1001326, 1001350, 1001657, 1001620, 1001627, 1001640, 1002534, 1002677, 1002503, 1002688, 1003880, 1006196, 1006225, 1006242, 1006732, 1006902, 1005683, 1009787, 1011126, 1011177, 1011707, 1011688, 1011693, 1011992, 1011995, 1012224, 1011689, 1011704, 1011993, 1012616, 1012619, 1000245, 1000260, 1000375, 1000492, 1000493, 1000494, 1000495, 1001016, 35, 1001028, 1000031, 1000247, 1000006, 1001656, 1002504, 1003104, 1004684, 1004682, 1005680, 1008041, 1009454, 1010192, 1011476, 1002383, 1011591, 1011588, 1011718, 1012048, 1
# ...

# %%
import requests
import pandas as pd

list_phones = pd.DataFrame()
for page_num in range(1, 5): #Number of pages to search through
    json_page = requests.get('https://shopee.co.id/api/v4/search/search_items?by=relevancy&keyword=salep%2088&limit=60&newest=0&order=desc&page_type=search&scenario=PAGE_GLOBAL_SEARCH&version=2' + str(page_num)).json()

    for df_shopee in json_page['items']['item_basic']:
        temp_df = pd.DataFrame([[df_shopee['name'], df_shopee['price_min']]], columns=['Name','price_min'])
        list_phones = list_phones.append(temp_df, sort=False).reset_index(drop=True)

print(list_phones)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-cc2d223dcfa2> in <module>
#       6     json_page = requests.get('https://shopee.co.id/api/v4/search/search_items?by=relevancy&keyword=salep%2088&limit=60&newest=0&order=desc&page_type=search&scenario=PAGE_GLOBAL_SEARCH&version=2' + str(page_num)).json()
#       7
# ----> 8     for df_shopee in json_page['items']['item_basic']:
#       9         temp_df = pd.DataFrame([[df_shopee['name'], df_shopee['price_min']]], columns=['Name','price_min'])
#      10         list_phones = list_phones.append(temp_df, sort=False).reset_index(drop=True)
#
# TypeError: list indices must be integers or slices, not str

# %%
df_shopee
# Out:
#   bff_meta error error_msg reserved_keyword suggestion_algorithm  \
# 0     None  None      None             None                 None
#
#                                            algorithm total_count nomore  \
# 0  eyJzZWFyY2giOiIwLmEuMzE2NkBFUklQUVBJV0ZNVVVWRl...        7789  False
#
#                                                items price_adjust  ...  \
# 0  [{'item_basic': {'itemid': 6815585430, 'shopid...         None  ...
#
#   show_disclaimer                                          json_data  \
# 0           False  CjpjOj07ZT1iO3BpZD1BO3dlYmxhYj0wOzIuYS40NzVAQk...
#
#                                        query_rewrite disclaimer_infos  \
# 0  {'fe_query_write_status': 0, 'rewrite_keyword'...               []
#
#   need_next_search                                         low_result  \
# 0             True  {'triggered': False, 'scenarios': None, 'total...
#
#   autoplay_info      food_item_info  \
# 0          None  {'total_count': 0}
#
# ...
