# %%
import pandas as pd
import logging
import numpy as np

logging.basicConfig(level=logging.INFO)

# %%
url = "https://id.wikipedia.org/wiki/Daftar_miliarder_Forbes"

# %%
def scrape(url):
    logging.info(f"Scraping website with url:'{url}'...")
    return pd.read_html(url, header=None)

# %%
dfs=scrape(url)[3]
# Out:
# INFO:root:Scraping website with url:'https://id.wikipedia.org/wiki/Daftar_miliarder_Forbes'...

# %%
dfs
# Out:
#    No.               Nama Kekayaan bersih (USD)  Usia       Kebangsaan  \
# 0  NaN         Jeff Bezos           $131 miliar    55  Amerika Serikat
# 1  NaN         Bill Gates          $96.5 miliar    63  Amerika Serikat
# 2  NaN     Warren Buffett          $82.5 miliar    88  Amerika Serikat
# 3  NaN    Bernard Arnault            $76 miliar    70          Prancis
# 4  NaN        Carlos Slim            $64 miliar    79          Meksiko
# 5  NaN     Amancio Ortega          $62.7 miliar    82          Spanyol
# 6  NaN      Larry Ellison          $62.5 miliar    74  Amerika Serikat
# 7  NaN    Mark Zuckerberg          $62.3 miliar    34  Amerika Serikat
# 8  NaN  Michael Bloomberg          $55.5 miliar    77  Amerika Serikat
# 9  NaN         Larry Page          $50.8 miliar    45  Amerika Serikat
#
#               Sumber kekayaan
# 0                      Amazon
# 1                   Microsoft
# 2          Berkshire Hathaway
# 3                        LVMH
# 4  América Móvil, Grupo Carso
# 5               Inditex, Zara
# 6          Oracle Corporation
# 7              Facebook, Inc.
# 8              Bloomberg L.P.
# 9               Alphabet Inc.

# %% [markdown]
# # Cleaning

# %%
import re

# %%
def is_money_miliar(string_money):
    return string_money.lower().endswith("miliar")

# %%
def transform_money_format(string_money):
    half_clean_string = string_money.lower().replace(",",".").replace(" ","")
    return re.sub(r"[?\[M\]miliar|", "", half_clean_string)

# %%
def transform(df,tahun):
    logging.info("Transforming DataFrame ...")
    
    columns_mapping={
        "Nama":"nama",
        "No." : "nomor_urut",
        "Kekayaan bersih (USD)":"kekayaan_bersih_usd_juta",
        "Usia" : "usia",
        "Kebangsaan" : "kebangsaan",
        "Sumber kekayaan":"sumber_kekayaan"
    }
    renamed_df = df.rename(columns=columns_mapping)
    
    #renamed_df["kekayaan_bersih_usd_juta"]=renamed_df["kekayaan_bersih_usd"].apply(
     #   lambda value: float(transform_money_format(value))*1000 if is_money_miliar(value) else float(transform_money_format(value))
    #)
    
    renamed_df["tahun"]=tahun
    
    return renamed_df[["nomor_urut","nama","kekayaan_bersih_usd_juta","usia","kebangsaan","sumber_kekayaan","tahun"]]

# %%
df_2021=transform(dfs,2021)
# Out:
# INFO:root:Transforming DataFrame ...

# %%
df_2021
# Out:
#    nomor_urut               nama kekayaan_bersih_usd_juta  usia  \
# 0         NaN         Jeff Bezos              $131 miliar    55
# 1         NaN         Bill Gates             $96.5 miliar    63
# 2         NaN     Warren Buffett             $82.5 miliar    88
# 3         NaN    Bernard Arnault               $76 miliar    70
# 4         NaN        Carlos Slim               $64 miliar    79
# 5         NaN     Amancio Ortega             $62.7 miliar    82
# 6         NaN      Larry Ellison             $62.5 miliar    74
# 7         NaN    Mark Zuckerberg             $62.3 miliar    34
# 8         NaN  Michael Bloomberg             $55.5 miliar    77
# 9         NaN         Larry Page             $50.8 miliar    45
#
#         kebangsaan             sumber_kekayaan  tahun
# 0  Amerika Serikat                      Amazon   2021
# 1  Amerika Serikat                   Microsoft   2021
# 2  Amerika Serikat          Berkshire Hathaway   2021
# 3          Prancis                        LVMH   2021
# 4          Meksiko  América Móvil, Grupo Carso   2021
# 5          Spanyol               Inditex, Zara   2021
# 6  Amerika Serikat          Oracle Corporation   2021
# 7  Amerika Serikat              Facebook, Inc.   2021
# 8  Amerika Serikat              Bloomberg L.P.   2021
# 9  Amerika Serikat               Alphabet Inc.   2021

# %%
df_2021['nomor_urut'] = np.arange(df_2021.shape[0])
df_2021['nomor_urut']=df_2021['nomor_urut']+1
df_2021['kekayaan_bersih_usd_juta'] = df_2021['kekayaan_bersih_usd_juta'].str.replace('miliar', '')
df_2021['kekayaan_bersih_usd_juta'] = df_2021['kekayaan_bersih_usd_juta'].replace(' ', '')
df_2021['kekayaan_bersih_usd_juta'] = df_2021['kekayaan_bersih_usd_juta'].str.replace('$', '')
df_2021
# Out:
#    nomor_urut               nama kekayaan_bersih_usd_juta  usia  \
# 0           1         Jeff Bezos                     131     55
# 1           2         Bill Gates                    96.5     63
# 2           3     Warren Buffett                    82.5     88
# 3           4    Bernard Arnault                      76     70
# 4           5        Carlos Slim                      64     79
# 5           6     Amancio Ortega                    62.7     82
# 6           7      Larry Ellison                    62.5     74
# 7           8    Mark Zuckerberg                    62.3     34
# 8           9  Michael Bloomberg                    55.5     77
# 9          10         Larry Page                    50.8     45
#
#         kebangsaan             sumber_kekayaan  tahun
# 0  Amerika Serikat                      Amazon   2021
# 1  Amerika Serikat                   Microsoft   2021
# 2  Amerika Serikat          Berkshire Hathaway   2021
# 3          Prancis                        LVMH   2021
# 4          Meksiko  América Móvil, Grupo Carso   2021
# 5          Spanyol               Inditex, Zara   2021
# 6  Amerika Serikat          Oracle Corporation   2021
# 7  Amerika Serikat              Facebook, Inc.   2021
# 8  Amerika Serikat              Bloomberg L.P.   2021
# 9  Amerika Serikat               Alphabet Inc.   2021

# %%
df_2021.dtypes
# Out:
# nomor_urut                   int64
# nama                        object
# kekayaan_bersih_usd_juta    object
# usia                         int64
# kebangsaan                  object
# sumber_kekayaan             object
# tahun                        int64
# dtype: object

# %%
df_2021['kekayaan_bersih_usd_juta']=df_2021.kekayaan_bersih_usd_juta.astype(float)*1000
df_2021
# Out:
#    nomor_urut               nama  kekayaan_bersih_usd_juta  usia  \
# 0           1         Jeff Bezos                  131000.0    55
# 1           2         Bill Gates                   96500.0    63
# 2           3     Warren Buffett                   82500.0    88
# 3           4    Bernard Arnault                   76000.0    70
# 4           5        Carlos Slim                   64000.0    79
# 5           6     Amancio Ortega                   62700.0    82
# 6           7      Larry Ellison                   62500.0    74
# 7           8    Mark Zuckerberg                   62300.0    34
# 8           9  Michael Bloomberg                   55500.0    77
# 9          10         Larry Page                   50800.0    45
#
#         kebangsaan             sumber_kekayaan  tahun
# 0  Amerika Serikat                      Amazon   2021
# 1  Amerika Serikat                   Microsoft   2021
# 2  Amerika Serikat          Berkshire Hathaway   2021
# 3          Prancis                        LVMH   2021
# 4          Meksiko  América Móvil, Grupo Carso   2021
# 5          Spanyol               Inditex, Zara   2021
# 6  Amerika Serikat          Oracle Corporation   2021
# 7  Amerika Serikat              Facebook, Inc.   2021
# 8  Amerika Serikat              Bloomberg L.P.   2021
# 9  Amerika Serikat               Alphabet Inc.   2021

# %%
df_2021['kekayaan_bersih_usd_juta'] = df_2021['kekayaan_bersih_usd_juta'].apply(lambda x: "${:.2f}".format((x/1)))
df_2021
# Out:
#    nomor_urut               nama kekayaan_bersih_usd_juta  usia  \
# 0           1         Jeff Bezos               $131000.00    55
# 1           2         Bill Gates                $96500.00    63
# 2           3     Warren Buffett                $82500.00    88
# 3           4    Bernard Arnault                $76000.00    70
# 4           5        Carlos Slim                $64000.00    79
# 5           6     Amancio Ortega                $62700.00    82
# 6           7      Larry Ellison                $62500.00    74
# 7           8    Mark Zuckerberg                $62300.00    34
# 8           9  Michael Bloomberg                $55500.00    77
# 9          10         Larry Page                $50800.00    45
#
#         kebangsaan             sumber_kekayaan  tahun
# 0  Amerika Serikat                      Amazon   2021
# 1  Amerika Serikat                   Microsoft   2021
# 2  Amerika Serikat          Berkshire Hathaway   2021
# 3          Prancis                        LVMH   2021
# 4          Meksiko  América Móvil, Grupo Carso   2021
# 5          Spanyol               Inditex, Zara   2021
# 6  Amerika Serikat          Oracle Corporation   2021
# 7  Amerika Serikat              Facebook, Inc.   2021
# 8  Amerika Serikat              Bloomberg L.P.   2021
# 9  Amerika Serikat               Alphabet Inc.   2021

# %% [markdown]
# # Loading (Storing to Database)

# %%
pip install psycopg2-binary==2.8.6
# Out:
# Requirement already satisfied: psycopg2-binary==2.8.6 in /Users/dwineta/miniconda3/lib/python3.7/site-packages (2.8.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install Flask-SQLAlchemy
# Out:
# Requirement already satisfied: Flask-SQLAlchemy in /Users/dwineta/miniconda3/lib/python3.7/site-packages (2.5.1)
# Requirement already satisfied: SQLAlchemy>=0.8.0 in /Users/dwineta/miniconda3/lib/python3.7/site-packages (from Flask-SQLAlchemy) (1.4.31)
# Requirement already satisfied: Flask>=0.10 in /Users/dwineta/miniconda3/lib/python3.7/site-packages (from Flask-SQLAlchemy) (2.0.2)
# Requirement already satisfied: greenlet!=0.4.17; python_version >= "3" and (platform_machine == "aarch64" or (platform_machine == "ppc64le" or (platform_machine == "x86_64" or (platform_machine == "amd64" or (platform_machine == "AMD64" or (platform_machine == "win32" or platform_machine == "WIN32")))))) in /Users/dwineta/miniconda3/lib/python3.7/site-packages (from SQLAlchemy>=0.8.0->Flask-SQLAlchemy) (1.1.2)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /Users/dwineta/miniconda3/lib/python3.7/site-packages (from SQLAlchemy>=0.8.0->Flask-SQLAlchemy) (4.11.1)
# Requirement already satisfied: click>=7.1.2 in /Users/dwineta/miniconda3/lib/python3.7/site-packages (from Flask>=0.10->Flask-SQLAlchemy) (7.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in /Users/dwineta/miniconda3/lib/python3.7/site-packages (from Flask>=0.10->Flask-SQLAlchemy) (2.0.1)
# Requirement already satisfied: Werkzeug>=2.0 in /Users/dwineta/miniconda3/lib/python3.7/site-packages (from Flask>=0.10->Flask-SQLAlchemy) (2.0.2)
# Requirement already satisfied: Jinja2>=3.0 in /Users/dwineta/miniconda3/lib/python3.7/site-packages (from Flask>=0.10->Flask-SQLAlchemy) (3.0.3)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /Users/dwineta/miniconda3/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->SQLAlchemy>=0.8.0->Flask-SQLAlchemy) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /Users/dwineta/miniconda3/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->SQLAlchemy>=0.8.0->Flask-SQLAlchemy) (3.7.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/dwineta/miniconda3/lib/python3.7/site-packages (from Jinja2>=3.0->Flask>=0.10->Flask-SQLAlchemy) (2.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine

# %%
DB_NAME = "postgres"
DB_USER = "user1"
DB_PASSWORD = "user1"
DB_HOST = "104.197.148.144"
DB_PORT = "5432"
CONNECTION_STRING = f"postgresql://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}"
TABLE_NAME = "dwineta-peserta_orang_terkaya_forbes"

# %%
CONNECTION_STRING
# Out:
# 'postgresql://user1:user1@104.197.148.144:5432/postgres'

# %%
def write_to_postgres(df,db_name,table_name,connection_string):
    engine = create_engine(connection_string)
    logging.info(f"Writing dataframe to database: '{db_name}',table: '{table_name}' ...")
    df.to_sql(name=table_name, con=engine, if_exists="replace",index=False)

# %%
write_to_postgres(df=df_2021,db_name=DB_NAME,table_name=TABLE_NAME, connection_string=CONNECTION_STRING)
# Out:
# INFO:root:Writing dataframe to database: 'postgres',table: 'dwineta-peserta_orang_terkaya_forbes' ...

# %%
def read_from_postgres(db_name,table_name,connection_string):
    engine=create_engine(connection_string)
    
    logging.info(f"reading postgres database:'{db_name}',table: '{table_name}' ...")
    return pd.read_sql_table(table_name,con=engine)

# %%
result_df = read_from_postgres(db_name=DB_NAME, table_name=TABLE_NAME, connection_string=CONNECTION_STRING)
# Out:
# INFO:root:reading postgres database:'postgres',table: 'dwineta-peserta_orang_terkaya_forbes' ...

# %%
print("Daftar Orang Terkaya di Indonesia:")
print(result_df.to_string())
# Out:
# Daftar Orang Terkaya di Indonesia:
#    nomor_urut               nama kekayaan_bersih_usd_juta  usia       kebangsaan             sumber_kekayaan  tahun
# 0           1         Jeff Bezos               $131000.00    55  Amerika Serikat                      Amazon   2021
# 1           2         Bill Gates                $96500.00    63  Amerika Serikat                   Microsoft   2021
# 2           3     Warren Buffett                $82500.00    88  Amerika Serikat          Berkshire Hathaway   2021
# 3           4    Bernard Arnault                $76000.00    70          Prancis                        LVMH   2021
# 4           5        Carlos Slim                $64000.00    79          Meksiko  América Móvil, Grupo Carso   2021
# 5           6     Amancio Ortega                $62700.00    82          Spanyol               Inditex, Zara   2021
# 6           7      Larry Ellison                $62500.00    74  Amerika Serikat          Oracle Corporation   2021
# 7           8    Mark Zuckerberg                $62300.00    34  Amerika Serikat              Facebook, Inc.   2021
# 8           9  Michael Bloomberg                $55500.00    77  Amerika Serikat              Bloomberg L.P.   2021
# 9          10         Larry Page                $50800.00    45  Amerika Serikat               Alphabet Inc.   2021
